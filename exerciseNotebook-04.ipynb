# %%
pip install Matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.1/165.1 kB 198.3 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 199.8 kB/s eta 0:00:0000:0100:02
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.4/255.4 kB 195.5 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 177.5 kB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.1/65.1 kB 246.9 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 139.4 kB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.9/106.9 kB 299.1 kB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 816.5 kB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

from pandas import DataFrame

# %%
data = {'names':['steve', 'john', 'richard', 'sarah', 'randy', 'micheal', 'julie'],
        'age':[20, 22, 20, 21, 24, 23, 22],
        'gender':['Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female'],
        'rank':[2, 1, 4, 5, 3, 7, 6]}

df = DataFrame(data)
df
# Out:
#      names  age  gender  rank
# 0    steve   20    Male     2
# 1     john   22    Male     1
# 2  richard   20    Male     4
# 3    sarah   21  Female     5
# 4    randy   24    Male     3
# 5  micheal   23    Male     7
# 6    julie   22  Female     6

# %%
plt.bar(df['names'], df['age'])
plt.xlabel('Names')
plt.ylabel('Age')
plt.title('Name/Age')
plt.show()

# %%
plot = sns.barplot(data=df, x='names', y='age')
plot.set_title('compare name Age')
# Out:
# Text(0.5, 1.0, 'compare name Age')

# %%
plt.plot(df['names'], df['age'])
plt.xlabel('Names')
plt.ylabel('Age')
plt.title('Name/Age')
plt.show()

# %%
plot = sns.lineplot(data=df, x='names', y='age')
plot.set_title('compare name Age')
# Out:
# Text(0.5, 1.0, 'compare name Age')

# %%
plt.pie(df['age'], labels = df['names'])
plt.title("Age Comparison")
plt.show()

# %%
colors = sns.color_palette('pastel')[0:5]
plt.pie(df['age'], labels = df['names'], colors = colors)
plt.show()

# %%
import numpy as np
from numpy.random import randn
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
from matplotlib import rcParams

# %%
x = range(1,10)
y = [1,2,3,4,0,4,3,2,1]
plt.plot(x,y)
#plt.show()

# %%
#address = '/workspaces/python-for-data-science-and-machine-learning-essential-training-part-1-3006708/data/mtcars.csv'
#/Users/farhoudkhoshnoud/Library/CloudStorage/OneDrive-Personal/Self Study/LinkedIn Learn Exercise/Python/PythonProject_ML102/data/mtcars.csv
address = './data/mtcars.csv'

cars = pd.read_csv(address)
cars.columns = ['car_names','mpg','cyl','disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']
mpg = cars['mpg']

# %%
mpg.plot()
# Out:
# <Axes: >

# %%
df = cars[['cyl', 'wt', 'mpg']]
df.plot()
# Out:
# <Axes: >

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 9 artists>

# %%
mpg.plot(kind='bar')
#mpg.plot(kind='barh')
# Out:
# <Axes: >

# %%
x = [1,2,3,4,0.5]
plt.pie(x)
plt.show()

# %%
plt.pie(x)
plt.savefig('pie_chart.png')
plt.show()

# %%
# %matplotlib inline
rcParams['figure.figsize']= 5,4

# %%
x = range(1,10)
y = [1,2,3,4,0,4,3,2,1]

fig = plt.figure()
ax = fig.add_axes([.1,.1,1,1])

ax.plot(x,y)

# %%
x = range(1,10)
y = [1,2,3,4,0,4,3,2,1]

fig = plt.figure()
ax = fig.add_axes([.1,.1,1,1])

ax.set_xlim([1,9])
ax.set_ylim([0,5])

ax.set_xticks([0,1,2,3,4,5,6,8,9,10])
ax.set_yticks([0,1,2,3,4,5])

ax.plot(x,y)

# %%
fig = plt.figure()
ax = fig.add_axes([.1,.1,1,1])

ax.set_xlim([1,9])
ax.set_ylim([0,5])

ax.grid()
ax.plot(x,y)

# %%
fig = plt.figure()
fig, (ax1, ax2) = plt.subplots(1,2)
ax1.plot(x)
#ax1.plot(y)
#ax1.plot(y,x)
ax2.plot(x,y)

# %% [markdown]
# ## 04_04

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
from pylab import rcParams

import seaborn as sb

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 5, 4
sb.set_style('whitegrid')

# %%
x = range(1, 10)
y = [1,2,3,4,0.5,4,3,2,1]

plt.bar(x, y)
# Out:
# <BarContainer object of 9 artists>

# %%
wide = [0.5, 0.5, 0.5, 0.9, 0.9, 0.9, 0.5, 0.5, 0.5]
color = ['salmon']
plt.bar(x, y, width=wide, color=color, align='center')
# Out:
# <BarContainer object of 9 artists>

# %%
#address = '/workspaces/python-for-data-science-and-machine-learning-essential-training-part-1-3006708/data/mtcars.csv'
address = './data/mtcars.csv'


cars = pd.read_csv(address)
cars.columns = ['car_names','mpg','cyl','disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']

df = cars[['cyl', 'mpg','wt']]
df.plot()
# Out:
# <Axes: >

# %%
color_theme = ['darkgray', 'lightsalmon', 'powderblue']
df.plot(color=color_theme)
# Out:
# <Axes: >

# %%
z = [1,2,3,4,0.5]
plt.pie(z)
plt.show()

# %%
color_theme = ['#A9A9A9', '#FFA07A', '#B0E0E6', '#FFE4C4', '#BDB76B']
plt.pie(z, colors = color_theme)
plt.show()

# %%
x1 = range(1,10)
y1 = [9, 8, 7, 6, 5, 4, 3, 2, 1]

plt.plot(x, y)
plt.plot(x1,y1)

# %%
plt.plot(x, y, ls = 'solid', lw=5)
plt.plot(x1,y1, ls='--', lw=10)

# %%
plt.plot(x, y, marker = '1', mew=20)
plt.plot(x1,y1, marker = '+', mew=15)

# %% [markdown]
# ## 04_05

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
from pylab import rcParams
import seaborn as sns

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 12,4
sns.set_style('whitegrid')

# %%
x = range(1,10)
y = [1,2,3,4,0.5,4,3,2,1]

plt.bar(x,y)

plt.xlabel('your x-axis label')
plt.ylabel('your y-axis label')
# Out:
# Text(0, 0.5, 'your y-axis label')

# %%
z = [1,2,3,4,0.5]
veh_type = ['bicycle', 'motorbike','car','van','stroller']
plt.pie(z, labels=veh_type)
plt.show()

# %%
#address = '/workspaces/python-for-data-science-and-machine-learning-essential-training-part-1-3006708/data/mtcars.csv'
address = './data/mtcars.csv'

cars = pd.read_csv(address)
cars.columns = ['car_names','mpg','cyl','disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']

mpg = cars.mpg

fig = plt.figure()
ax = fig.add_axes([.1,.1,1,1])

mpg.plot()

ax.set_xticks(range(32))

ax.set_xticklabels(cars.car_names, rotation=60, fontsize='medium')
ax.set_title('Miles Per Gallon of Cars in mtcars')

ax.set_xlabel('car names')
ax.set_ylabel('miles/gal')
# Out:
# Text(0, 0.5, 'miles/gal')

# %%
plt.pie(z)
plt.legend(veh_type, loc='best')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([.1,.1,1,1])

mpg.plot()

ax.set_xticks(range(32))

ax.set_xticklabels(cars.car_names, rotation=60, fontsize='medium')
ax.set_title('Miles Per Gallon of Cars in mtcars')

ax.set_xlabel('car names')
ax.set_ylabel('miles/gal')

ax.legend(loc='best')

# %%
mpg.max()
# Out:
# np.float64(33.9)

# %%
fig = plt.figure()
ax = fig.add_axes([.1,.1,1,1])

mpg.plot()

ax.set_xticks(range(32))

ax.set_xticklabels(cars.car_names, rotation=60, fontsize='medium')
ax.set_title('Miles Per Gallon of Cars in mtcars')

ax.set_xlabel('car names')
ax.set_ylabel('miles/gal')

ax.set_ylim([0,45])

ax.annotate('Toyota Corolla', xy=(19,33.9), xytext=(21,35),arrowprops=dict(facecolor='black', shrink=0.05))

ax.legend(loc='best')

# %%
rg = range(32)
print(rg)
# Out:
# range(0, 32)

# %% [markdown]
# ## 04_06

# %%
import numpy as np
from numpy.random import randn
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
from pylab import rcParams
import seaborn as sns

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 5, 4
sns.set_style('whitegrid')

# %%
#address = '/workspaces/python-for-data-science-and-machine-learning-essential-training-part-1-3006708/data/Superstore-Sales.csv'

address = './data/Superstore-Sales.csv'

df= pd.read_csv(address, index_col='Order Date', encoding= 'cp1252', parse_dates=True)

df.head()
# Out:
#             Row ID  Order ID Order Priority  Order Quantity       Sales  \
# Order Date
# 2010-10-13       1         3            Low               6    261.5400
# 2012-10-01      49       293           High              49  10123.0200
# 2012-10-01      50       293           High              27    244.5700
# 2011-07-10      80       483           High              30   4965.7595
# 2010-08-28      85       515  Not Specified              19    394.2700
#
#             Discount       Ship Mode   Profit  Unit Price  Shipping Cost  \
# Order Date
# 2010-10-13      0.04     Regular Air  -213.25       38.94          35.00
# 2012-10-01      0.07  Delivery Truck   457.81      208.16          68.02
# 2012-10-01      0.01     Regular Air    46.71        8.69           2.99
# 2011-07-10      0.08     Regular Air  1198.97      195.99           3.99
# 2010-08-28      0.08     Regular Air    30.94       21.78           5.94
#
# ...

# %%
df['Order Quantity'].plot()
# Out:
# <Axes: xlabel='Order Date'>

# %%
df2 = df.sample(n=100, random_state=25, axis=0)

plt.xlabel('Order Date')
plt.ylabel('Order Quantity')

plt.title('Superstore Sales')

df2['Order Quantity'].plot()
# Out:
# <Axes: title={'center': 'Superstore Sales'}, xlabel='Order Date', ylabel='Order Quantity'>

# %% [markdown]
# ## 04_07

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

from pandas.plotting import scatter_matrix

import matplotlib.pyplot as plt
from pylab import rcParams
import seaborn as sns

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 5, 6
sns.set_style('whitegrid')

# %%
#address = '/workspaces/python-for-data-science-and-machine-learning-essential-training-part-1-3006708/data/mtcars.csv'
#/Users/farhoudkhoshnoud/Library/CloudStorage/OneDrive-Personal/Self Study/LinkedIn Learn Exercise/Python/Python for Data Science and Machine Learning Essential Training Part 1/pyML1_Repo/python-for-data-science-and-machine-learning-essential-training-part-1-3006708/data/mtcars.csv
address = './data/mtcars.csv'

cars = pd.read_csv(address)

cars.columns = ['car_names','mpg','cyl','disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']
cars.index = cars.car_names

mpg = cars['mpg']

mpg.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.hist(mpg)
plt.plot()
# Out:
# []

# %%
sns.displot(mpg)

# %%
cars.plot(kind='scatter', x='hp', y='mpg', c=['darkgray'],s=150)
# Out:
# <Axes: xlabel='hp', ylabel='mpg'>

# %%
sns.regplot(x='hp', y='mpg', data=cars, scatter=True)
# Out:
# <Axes: xlabel='hp', ylabel='mpg'>

# %%
sns.pairplot(cars)

#plt.savefig('pairplot_chart.png')

# %%
cars_subset = cars[['mpg', 'disp', 'hp', 'wt']]
sns.pairplot(cars_subset)
plt.show()

# %%
cars.boxplot(column='mpg', by='am')
cars.boxplot(column='wt', by='am')
# Out:
# <Axes: title={'center': 'wt'}, xlabel='am'>

# %%
sns.boxplot(x='am', y='mpg', data=cars, hue='am', palette='hls')
# Out:
# <Axes: xlabel='am', ylabel='mpg'>

# %%
sns.boxplot(x='am', y='mpg', data=cars, hue='am', palette='deep')
# Out:
# <Axes: xlabel='am', ylabel='mpg'>

# %%
cars.head()
# Out:
#                            car_names   mpg  cyl   disp   hp  drat     wt  \
# car_names
# Mazda RX4                  Mazda RX4  21.0    6  160.0  110  3.90  2.620
# Mazda RX4 Wag          Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875
# Datsun 710                Datsun 710  22.8    4  108.0   93  3.85  2.320
# Hornet 4 Drive        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215
# Hornet Sportabout  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440
#
#                     qsec  vs  am  gear  carb
# car_names
# Mazda RX4          16.46   0   1     4     4
# Mazda RX4 Wag      17.02   0   1     4     4
# Datsun 710         18.61   1   1     4     1
# Hornet 4 Drive     19.44   1   0     3     1
# Hornet Sportabout  17.02   0   0     3     2
